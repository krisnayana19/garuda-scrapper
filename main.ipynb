# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://garuda.kemdikbud.go.id/documents?page={}&q=sosiologi"
mainurl = "https://garuda.kemdikbud.go.id"

df = pd.DataFrame.from_dict({
    'name': [],
    'published_at': [],
    'abstract': [],
    'publisher': [],
    'company_publisher': [],
    'creator': [],
    'category': [],
    'web_publisher': [],
    'link_publisher': [],
    # 'ris_citation': [], 
    # 'bibtex_citation': [], 
    # 'ori_source': [], 
    # 'ori_download': [], 
    # 'scholar': [],
})

for i in range(1):
    uri = f"{url.format(i)}"

    result = requests.get(url=uri).content
    doc = BeautifulSoup(result, "html.parser")
    article = doc.findAll('div', class_="article-item")

    for articles in article:
        articletitle = articles.find('a')
        href = articletitle.get('href')
        link_doc = mainurl + href
        spec = requests.get(url=link_doc).content

        journal = BeautifulSoup(spec, "html.parser")
        journal_name = journal.find('h3', class_="ui header").text
        journal_publish = journal.find('div', class_="four wide column").text
        journal_publish_clear = journal_publish.replace("\n", "")
        journal_abstract = journal.find('div', class_="abstract-article").text
        
        segment = journal.find_all("div", class_="ui segment")
        journal_writter_dump = journal.find('div', class_="ui segment article-display")
        journal_writter = journal_writter_dump.find('div')
        if journal_writter:
            middle_div = journal_writter.find('div')
            if middle_div:
                middle_a = middle_div.find('a').text
          
        # journal_writter_fix = journal_writter.find('a').text
        publisher = journal.find("div", class_="ui segment j-art-display")
        name_publisher_meta = publisher.find("div", class_="j-title")
        web_publisher_meta = publisher.find("div", class_="j-website")
        pub_publisher_meta = publisher.find("div", class_="j-pub-name")
        category_publisher_meta = publisher.find("a", class_="ui tag label grey mini").text
        name_publisher = name_publisher_meta.find("a").text
        web_publisher = web_publisher_meta.find("a")
        pub_publisher = pub_publisher_meta.find("a").text
        link_pub_publisher = pub_publisher_meta.find("a")

        web_publisher_fix = web_publisher['href']

        for div in segment:
            item_elements = div.find_all("div", class_="item")
            linked = []
            keys = ['ris_citation', 'bibtex_citation', 'ori_source', 'ori_download', 'scholar']
            for a in item_elements:
                anchor = a.find_all("a", class_="content")
                for index, link in enumerate(anchor):
                    href = link['href']
                    # print(href)
                    linked.append(href)
        
        new_list = [{key:value for key in keys} for value in linked]
        new_row = {'name': journal_name.replace("\n", ""),
            'published_at': journal_publish_clear.replace("Article InfoPublish Date", ""),
            'abstract': journal_abstract.replace("\n", ""),
            'publisher': name_publisher.replace("\n", ""),
            'company_publisher': pub_publisher.replace("\n", ""),
            'category': category_publisher_meta,
            'creator': middle_a,
            'web_publisher': web_publisher_fix.replace("\n", ""),
            'link_publisher': mainurl + link_pub_publisher['href'],
            # 'ris_citation': new_list[0]['ris_citation'],
            # 'bibtex_citation': new_list[0]['bibtex_citation'],
            # 'ori_source': new_list[0]['ori_source'],
            # 'ori_download': new_list[3]['ori_download'],
            # 'scholar': new_list[4]['scholar']
        }
        row_new_df = pd.DataFrame([new_row])
        df = pd.concat([df, row_new_df], ignore_index=True)

# %%
df.head(100)
# Out:
#                                                 name  published_at  \
# 0  Gamifikasi Pembelajaran Sosiologi Materi Ragam...   20 May 2020
# 1  NINGEN KANKEI TOKOH UTAMA DALAM NOVEL SHINSHO ...   04 Dec 2012
# 2  ASPEK PERKAWINAN DALAM NOVEL BENANG-BENANG SAM...   22 Dec 2014
# 3  Narasi Sejarah Novel Tambora Karya Agus Sumbog...   01 Feb 2018
# 4  Analisis Sosiologi Sastra Pada Kumpulan Cerkak...   19 Apr 2017
# 5  Kajian Sosiologi Cerbung Mandhor Pasar Tandhas...   17 Apr 2017
# 6  Analisis Sosiologi Sastra Dalam Novel Prau Get...   29 Apr 2017
# 7  Konflik Sosial Dalam Novel Cintrong Paju-Pat K...   22 May 2015
# 8  Kajian Sosiologi dan Nilai Moralpada Novel Ron...   07 May 2015
# 9  ANALISIS SOSIOLOGI SASTRA NOVEL PEREMPUAN KARY...   29 Sep 2018
#
#                                             abstract  \
# 0  Abstrak: Desain Pembelajaran Gamifikasi adalah...
# 1  Society consists of several individuals who in...
# 2  This study, entitled "Aspek Perkawinan dalam N...
# 3  The data of this study were taken from an Indo...
# 4  Abstrak: Penelitian ini bertujuan untuk mendes...
# 5  Abstrak: Penelitian ini bertujuan: (1) mendesk...
# 6  Abstrak.Penelitian ini bertujuan untuk mendesk...
# 7  Abstrak: Penelitian ini bertujuan mendeskripsi...
# 8  Abstrak : Penelitian ini bertujuan untuk (1) m...
# 9  Abstrak: Penelitian ini bertujuan untuk mendes...
#
#                                            publisher  \
# 0           JKTP: Jurnal Kajian Teknologi Pendidikan
# 1                                            HUMANIS
# 2                                            HUMANIS
# 3                                            HUMANIS
# 4         ADITYA - Pendidikan Bahasa dan Sastra Jawa
# 5         ADITYA - Pendidikan Bahasa dan Sastra Jawa
# 6         ADITYA - Pendidikan Bahasa dan Sastra Jawa
# 7         ADITYA - Pendidikan Bahasa dan Sastra Jawa
# 8         ADITYA - Pendidikan Bahasa dan Sastra Jawa
# 9  Jurnal Bahtera - Jurnal Pendidikan Bahasa dan ...
#
#                     company_publisher                  creator   category  \
# 0           Universitas Negeri Malang            Luis Rumianda      Other
# 1                 Universitas Udayana  Kadek Wahyu Dwi Hartadi       Arts
# 2                 Universitas Udayana      Ni Kadek Dwijayanti       Arts
# 3                 Universitas Udayana           Ardini Mulyadi       Arts
# 4  Universitas Muhammadiyah Purworejo       Faqih Abdurrokhman  Education
# 5  Universitas Muhammadiyah Purworejo      Dona Agnes Pangesti  Education
# 6  Universitas Muhammadiyah Purworejo                 Sar dono  Education
# 7  Universitas Muhammadiyah Purworejo            Emy Ipritania  Education
# 8  Universitas Muhammadiyah Purworejo      Nur Fitria Anggaeni  Education
# 9  Universitas Muhammadiyah Purworejo    Nursitatun Nursitatun  Education
#
#                                        web_publisher  \
# 0            http://journal2.um.ac.id/index.php/jktp
# 1            https://ojs.unud.ac.id/index.php/sastra
# 2            https://ojs.unud.ac.id/index.php/sastra
# 3            https://ojs.unud.ac.id/index.php/sastra
# 4       http://ejournal.umpwr.ac.id/index.php/aditya
# 5       http://ejournal.umpwr.ac.id/index.php/aditya
# 6       http://ejournal.umpwr.ac.id/index.php/aditya
# 7       http://ejournal.umpwr.ac.id/index.php/aditya
# 8       http://ejournal.umpwr.ac.id/index.php/aditya
# 9  http://ejournal.umpwr.ac.id/index.php/surya-ba...
#
#                                      link_publisher
# 0  https://garuda.kemdikbud.go.id/publisher/view/16
# 1  https://garuda.kemdikbud.go.id/publisher/view/38
# 2  https://garuda.kemdikbud.go.id/publisher/view/38
# 3  https://garuda.kemdikbud.go.id/publisher/view/38
# 4  https://garuda.kemdikbud.go.id/publisher/view/25
# 5  https://garuda.kemdikbud.go.id/publisher/view/25
# 6  https://garuda.kemdikbud.go.id/publisher/view/25
# 7  https://garuda.kemdikbud.go.id/publisher/view/25
# 8  https://garuda.kemdikbud.go.id/publisher/view/25
# 9  https://garuda.kemdikbud.go.id/publisher/view/25

# %%
df.to_csv('garuda_grc.csv', index=False)

# %%
df.to_excel('garuda_grc.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.to_excel('garuda_grc.xlsx', index=False)
#
# File c:\Users\Hamba Notebook\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353     engine_kwargs=engine_kwargs,
#    2354 )
#
# File c:\Users\Hamba Notebook\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\excel.py:946, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     942     need_save = False
#     943 else:
#     944     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     945     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 946     writer = ExcelWriter(  # type: ignore[abstract]
#     947         writer,
#     948         engine=engine,
#     949         storage_options=storage_options,
#     950         engine_kwargs=engine_kwargs,
#     951     )
#     952     need_save = True
#     954 try:
#
# File c:\Users\Hamba Notebook\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)
#      66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('indonesian')

# Inisialisasi stop words dan stemmer
stop_words = set(stopwords.words('indonesian'))  # Sesuaikan dengan bahasa yang sesuai
stemmer = PorterStemmer()

# Fungsi untuk melakukan text preprocessing pada abstrak
def preprocess_abstract(abstract):
    #menghapus tanda baca
    abstract = re.sub(r'[^\w\s]', '', abstract)

    # Tokenisasi kata-kata dalam abstrak
    words = word_tokenize(abstract)

    # Mengubah kata-kata menjadi huruf kecil
    words = [word.lower() for word in words]

    # Menghapus stopwords
    words = [word for word in words if word not in stop_words]

    # Stemming (opsional)
    words = [stemmer.stem(word) for word in words]

    # Menggabungkan kata-kata kembali menjadi teks
    preprocessed_abstract = ' '.join(words)

    return preprocessed_abstract

# Terapkan fungsi preprocess_abstract pada kolom abstrak dalam DataFrame
df['preprocessed_abstract'] = df['abstract'].apply(preprocess_abstract)

# Tampilkan DataFrame dengan kolom abstrak yang telah di-preprocess
print(df[['abstract', 'preprocessed_abstract']])
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Hamba
# [nltk_data]     Notebook\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Hamba
# [nltk_data]     Notebook\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Error loading indonesian: Package 'indonesian' not found
# [nltk_data]     in index
#                                             abstract  \
# 0  Abstrak: Desain Pembelajaran Gamifikasi adalah...
# 1  Society consists of several individuals who in...
# 2  This study, entitled "Aspek Perkawinan dalam N...
# 3  The data of this study were taken from an Indo...
# 4  Abstrak: Penelitian ini bertujuan untuk mendes...
# 5  Abstrak: Penelitian ini bertujuan: (1) mendesk...
# 6  Abstrak.Penelitian ini bertujuan untuk mendesk...
# 7  Abstrak: Penelitian ini bertujuan mendeskripsi...
# 8  Abstrak : Penelitian ini bertujuan untuk (1) m...
# 9  Abstrak: Penelitian ini bertujuan untuk mendes...
#
#                                preprocessed_abstract
# 0  abstrak : desain pembelajaran gamifikasi desai...
# 1  societi consist of sever individu who interact...
# 2  thi studi , entitl `` aspek perkawinan novel b...
# 3  the data of thi studi were taken from an indon...
# 4  abstrak : penelitian bertujuan mendeskripsikan...
# 5  abstrak : penelitian bertujuan : ( 1 ) mendesk...
# 6  abstrak.penelitian bertujuan mendeskripsikan :...
# 7  abstrak : penelitian bertujuan mendeskripsikan...
# 8  abstrak : penelitian bertujuan ( 1 ) mendeskri...
# 9  abstrak : penelitian bertujuan mendeskripsikan...

# %%
excel_file = 'hasil_preprocessing.xlsx'  # Nama file Excel yang akan digunakan
df.to_excel(excel_file, index=False)  # Menyimpan DataFrame ke dalam file Excel

print(f"Data telah disimpan dalam file Excel: {excel_file}")
# Out:
# Data telah disimpan dalam file Excel: hasil_preprocessing.xlsx
